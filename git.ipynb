# %%
from google.colab import drive
import os
drive.mount('/content/drive/')
os.chdir('/content/drive/MyDrive/MSU/EduNet')
# !ls -l
# Out:
# Mounted at /content/drive/
# total 4
# drwx------ 10 root root 4096 Dec 10 03:47 MyDrive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4a2498ea4b40> in <module>()
#       3 drive.mount('/content/drive/')
#       4 get_ipython().system("ls -l '/content/drive/'")
# ----> 5 os.chdir('/content/drive/MSU/EduNet')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MSU/EduNet'

# %%
os.chdir('/content/drive/MyDrive/MSU/EduNet')

# %%
import os
from getpass import getpass
import urllib

user = input('Username: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format
repo_name = "github.com/EPC-MSU/EduNet.git"
cmd_string = 'git clone https://{0}:{1}@{2}}'.format(user, password, repo_name)
exit_code = os.system(cmd_string)
print(exit_code)
cmd_string, password = "", "" # removing the password from the variable

# %%
# !git status
# !git fetch --all
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	0. Org.ipynb
# 	1. Excercise.ipynb
# 	1. Intro.gslides
# 	1. Intro_v0.gslides
# 	1.Intro.ipynb
# 	2. Linear classifier.gslides
# 	git.ipynb
# 	"\320\232\320\276\320\274\320\265\320\275\321\202\320\260\321\200\320\270\320\270 \320\272 \320\277\320\265\321\200\320\262\320\276\320\270\314\206 \320\273\320\265\320\272\321\206\320\270\320\270.gdoc"
#
# nothing added to commit but untracked files present (use "git add" to track)
# Fetching origin
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 75 (delta 11), reused 73 (delta 9), pack-reused 0
# Unpacking objects: 100% (75/75), done.
# From https://github.com/EPC-MSU/EduNet
#    e5bb989..ce25671  main       -> origin/main

# %%
#%%shell

# !sudo git add source/L1_Intro/1_Intro.gslides
# Out:
# error: open("source/L1_Intro/1_Intro.gslides"): Operation not supported
# error: unable to index file source/L1_Intro/1_Intro.gslides
# fatal: adding files failed
